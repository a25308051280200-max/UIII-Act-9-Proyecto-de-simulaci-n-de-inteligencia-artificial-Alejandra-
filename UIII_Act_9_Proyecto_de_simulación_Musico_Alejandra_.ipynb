# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280200-max/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Alejandra-/blob/main/UIII_Act_9_Proyecto_de_simulaci%C3%B3n_Musico_Alejandra_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### UIII Act 10
# ### Fecha 25/Mayo/2026
# ### Proyecto de simulación de inteligencia artificial  utiliza Lista,con if, else, elif  while tipo Menu
# ### Alejandra Rivera Valenzuela NL=49
# ### $ Musico $

# %%
# LISTA VACIA
musicos = []

# DICCIONARIO VACIO
losmusicos = {}

print("🎵 SISTEMA IA DE MUSICOS 🎵")

while True:
    print("\n===== MENU =====")
    print("1. Registrar musico")
    print("2. Mostrar musicos")
    print("3. Buscar musico")
    print("4. Eliminar musico")
    print("5. Salir")
    opcion = input("Selecciona una opcion: ")
    # REGISTRAR
    if opcion == "1":
        nombre = input("Nombre del musico: ")
        genero = input("Genero musical: ")
        edad = input("Edad: ")
        # DICCIONARIO
        losmusicos = {
            "nombre": nombre,
            "genero": genero,
            "edad": edad
        }
        # GUARDAR EN LISTA
        musicos.append(losmusicos)
        print("✅ Musico registrado correctamente")
    # MOSTRAR
    elif opcion == "2":
        if len(musicos) == 0:
            print("⚠️ La lista esta vacia")
        else:
            print("\n🎤 LISTA DE MUSICOS")
            contador = 1
            # CICLO FOR
            for musico in musicos:
                print("\nMusico", contador)
                print("Nombre:", musico["nombre"])
                print("Genero:", musico["genero"])
                print("Edad:", musico["edad"])
                contador = contador + 1
    # BUSCAR
    elif opcion == "3":
        buscar = input("Escribe el nombre del musico: ")
        encontrado = False
        for musico in musicos:
            if musico["nombre"] == buscar:
                print("\n🎶 Musico encontrado")
                print("Nombre:", musico["nombre"])
                print("Genero:", musico["genero"])
                print("Edad:", musico["edad"])
                encontrado = True
        if encontrado == False:
            print("❌ Musico no encontrado")
    # ELIMINAR
    elif opcion == "4":
        eliminar = input("Nombre del musico a eliminar: ")
        encontrado = False
        for musico in musicos:
            if musico["nombre"] == eliminar:
                musicos.remove(musico)
                print("🗑️ Musico eliminado")
                encontrado = True
        if encontrado == False:
            print("❌ No existe ese musico")
    # SALIR
    elif opcion == "5":

        print("👋 Gracias por usar el sistema")
        break

    # OPCION INVALIDA
    else:

        print("⚠️ Opcion incorrecta")
        print("Programa Rializado por Alejandra Rivera valenzuela NL = 49 ")
# Out:
# 🎵 SISTEMA IA DE MUSICOS 🎵
#
# ===== MENU =====
# 1. Registrar musico
# 2. Mostrar musicos
# 3. Buscar musico
# 4. Eliminar musico
# 5. Salir
# Selecciona una opcion: 1
# Nombre del musico: Isa
# Genero musical: Mariachi
# Edad: 30
# ✅ Musico registrado correctamente
#
# ===== MENU =====
# 1. Registrar musico
# 2. Mostrar musicos
# 3. Buscar musico
# 4. Eliminar musico
# 5. Salir
# Selecciona una opcion: 1
# Nombre del musico: Adan
# Genero musical: Hip Hop
# Edad: 25
# ✅ Musico registrado correctamente
#
# ===== MENU =====
# 1. Registrar musico
# 2. Mostrar musicos
# 3. Buscar musico
# 4. Eliminar musico
# 5. Salir
# Selecciona una opcion: 1
# Nombre del musico: Ever
# Genero musical: Musica clasica
# Edad: 20
# ✅ Musico registrado correctamente
#
# ===== MENU =====
# 1. Registrar musico
# 2. Mostrar musicos
# 3. Buscar musico
# 4. Eliminar musico
# 5. Salir
# Selecciona una opcion: 1
# Nombre del musico: Jose
# Genero musical: Mariachi
# Edad: 50
# ✅ Musico registrado correctamente
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280200-max/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Alejandra-/refs/heads/main/musicooooo.png)
